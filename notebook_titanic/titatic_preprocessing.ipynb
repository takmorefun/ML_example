# %% [markdown]
# ### kaggleのtitanic dataの可視化及びモデル学習の為の前処理用notebook

# %%
#モジュールのインポート
import pandas as pd
import numpy as np
import math
import re
from scipy.sparse import csr_matrix

from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns; sns.set(); sns.set_palette('husl')
import matplotlib as mpl
mpl.rcParams['font.family'] = 'Arial Unicode MS'  # to use Japanese in plots
from pprint import pprint

# %%
df_train = pd.read_csv("../data/kaggle/titanic/train.csv",encoding="utf-8-sig")
df_test = pd.read_csv("../data/kaggle/titanic/test.csv",encoding="utf-8-sig")
df_gender_submission = pd.read_csv("../data/kaggle/titanic/gender_submission.csv",encoding="utf-8-sig")

# %%
df_train["data_type"] = "train"
df_test["data_type"] = "test"

# %%
df_test = df_test.merge(df_gender_submission, on=['PassengerId'])

# %%
df_all = pd.concat([df_train, df_test], axis =0).reset_index(drop=True)

# %%
#欠損値の確認
df_all.isnull().sum()
# Out:
# Age             263
# Cabin          1014
# Embarked          2
# Fare              1
# Name              0
# Parch             0
# PassengerId       0
# Pclass            0
# Sex               0
# SibSp             0
# Survived          0
# Ticket            0
# data_type         0
# dtype: int64

# %% [markdown]
# ### カラムの一覧
# - PassengerId – 乗客識別ユニークID
# - Survived – 生存フラグ（0=死亡、1=生存）
# - Pclass – チケットクラス
# - Name – 乗客の名前
# - Sex – 性別（male=男性、female＝女性）
# - Age – 年齢
# - SibSp – タイタニックに同乗している兄弟/配偶者の数
# - parch – タイタニックに同乗している親/子供の数
# - ticket – チケット番号
# - fare – 料金
# - cabin – 客室番号
# - Embarked – 出港地（タイタニックへ乗った港）

# %%
sex_counts = df_train['Sex'].value_counts()
plt.figure(figsize=(8, 6))
sns.barplot(x=sex_counts.index, y=sex_counts.values)
plt.title('性別の分布', fontsize=20)
plt.show()

# %%
data_counts = df_train['Embarked'].value_counts()
plt.figure(figsize=(8, 6))
sns.barplot(x=data_counts.index, y=data_counts.values)
plt.title('出港地の分布', fontsize=20)
plt.show()

# %%
sex_counts = df_test['Cabin'].value_counts()[:30]
plt.figure(figsize=(20, 12))
sns.barplot(x=sex_counts.index, y=sex_counts.values)
plt.title('客室の分布', fontsize=20)
plt.show()

# %%
cabin_not_nan =df_train['Cabin'].dropna().index

# %%
df_train.iloc[cabin_not_nan]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# 23            24         1       1
# 27            28         0       1
# 31            32         1       1
# 52            53         1       1
# 54            55         0       1
# 55            56         1       1
# 61            62         1       1
# 62            63         0       1
# 66            67         1       2
# 75            76         0       3
# 88            89         1       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 123          124         1       2
# 124          125         0       1
# 128          129         1       3
# 136          137         1       1
# 137          138         0       1
# 139          140         0       1
# 148          149         0       2
# ..           ...       ...     ...
# 751          752         1       3
# 759          760         1       1
# 763          764         1       1
# 765          766         1       1
# 772          773         0       2
# 776          777         0       3
# 779          780         1       1
# 781          782         1       1
# 782          783         0       1
# 789          790         0       1
# 796          797         1       1
# 802          803         1       1
# 806          807         0       1
# 809          810         1       1
# 815          816         0       1
# 820          821         1       1
# 823          824         1       3
# 829          830         1       1
# 835          836         1       1
# 839          840         1       1
# 849          850         1       1
# 853          854         1       1
# 857          858         1       1
# 862          863         1       1
# 867          868         0       1
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 54                      Ostby, Mr. Engelhart Cornelius    male  65.0      0
# 55                                   Woolner, Mr. Hugh    male   NaN      0
# 61                                 Icard, Miss. Amelie  female  38.0      0
# 62                         Harris, Mr. Henry Birkhardt    male  45.0      1
# 66                        Nye, Mrs. (Elizabeth Ramell)  female  29.0      0
# 75                             Moen, Mr. Sigurd Hansen    male  25.0      0
# 88                          Fortune, Miss. Mabel Helen  female  23.0      3
# 92                         Chaffee, Mr. Herbert Fuller    male  46.0      1
# 96                           Goldschmidt, Mr. George B    male  71.0      0
# 97                     Greenfield, Mr. William Bertram    male  23.0      0
# 102                          White, Mr. Richard Frasar    male  21.0      0
# 110                     Porter, Mr. Walter Chamberlain    male  47.0      0
# 118                           Baxter, Mr. Quigg Edmond    male  24.0      0
# 123                                Webber, Miss. Susan  female  32.5      0
# 124                        White, Mr. Percival Wayland    male  54.0      0
# 128                                  Peter, Miss. Anna  female   NaN      1
# 136                       Newsom, Miss. Helen Monypeny  female  19.0      0
# 137                        Futrelle, Mr. Jacques Heath    male  37.0      1
# 139                                 Giglio, Mr. Victor    male  24.0      0
# 148           Navratil, Mr. Michel ("Louis M Hoffman")    male  36.5      0
# ..                                                 ...     ...   ...    ...
# 751                                Moor, Master. Meier    male   6.0      0
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...  female  33.0      0
# 763          Carter, Mrs. William Ernest (Lucile Polk)  female  36.0      1
# 765               Hogeboom, Mrs. John C (Anna Andrews)  female  51.0      1
# 772                                  Mack, Mrs. (Mary)  female  57.0      0
# 776                                   Tobin, Mr. Roger    male   NaN      0
# 779  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...  female  43.0      0
# 781          Dick, Mrs. Albert Adrian (Vera Gillespie)  female  17.0      1
# 782                             Long, Mr. Milton Clyde    male  29.0      0
# 789                           Guggenheim, Mr. Benjamin    male  46.0      0
# 796                        Leader, Dr. Alice (Farnham)  female  49.0      0
# 802                Carter, Master. William Thornton II    male  11.0      1
# 806                             Andrews, Mr. Thomas Jr    male  39.0      0
# 809     Chambers, Mrs. Norman Campbell (Bertha Griggs)  female  33.0      1
# 815                                   Fry, Mr. Richard    male   NaN      0
# 820  Hays, Mrs. Charles Melville (Clara Jennings Gr...  female  52.0      1
# 823                                 Moor, Mrs. (Beila)  female  27.0      0
# 829          Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0      0
# 835                        Compton, Miss. Sara Rebecca  female  39.0      1
# 839                               Marechal, Mr. Pierre    male   NaN      0
# 849       Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female   NaN      1
# 853                          Lines, Miss. Mary Conover  female  16.0      0
# 857                             Daly, Mr. Peter Denis     male  51.0      0
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 867               Roebling, Mr. Washington Augustus II    male  31.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch       Ticket      Fare        Cabin Embarked data_type
# 1        0     PC 17599   71.2833          C85        C     train
# 3        0       113803   53.1000         C123        S     train
# 6        0        17463   51.8625          E46        S     train
# 10       1      PP 9549   16.7000           G6        S     train
# 11       0       113783   26.5500         C103        S     train
# 21       0       248698   13.0000          D56        S     train
# 23       0       113788   35.5000           A6        S     train
# 27       2        19950  263.0000  C23 C25 C27        S     train
# 31       0     PC 17569  146.5208          B78        C     train
# 52       0     PC 17572   76.7292          D33        C     train
# 54       1       113509   61.9792          B30        C     train
# 55       0        19947   35.5000          C52        S     train
# 61       0       113572   80.0000          B28      NaN     train
# 62       0        36973   83.4750          C83        S     train
# 66       0   C.A. 29395   10.5000          F33        S     train
# 75       0       348123    7.6500        F G73        S     train
# 88       2        19950  263.0000  C23 C25 C27        S     train
# 92       0  W.E.P. 5734   61.1750          E31        S     train
# 96       0     PC 17754   34.6542           A5        C     train
# 97       1     PC 17759   63.3583      D10 D12        C     train
# 102      1        35281   77.2875          D26        S     train
# 110      0       110465   52.0000         C110        S     train
# 118      1     PC 17558  247.5208      B58 B60        C     train
# 123      0        27267   13.0000         E101        S     train
# 124      1        35281   77.2875          D26        S     train
# 128      1         2668   22.3583        F E69        C     train
# 136      2        11752   26.2833          D47        S     train
# 137      0       113803   53.1000         C123        S     train
# 139      0     PC 17593   79.2000          B86        C     train
# 148      2       230080   26.0000           F2        S     train
# ..     ...          ...       ...          ...      ...       ...
# 751      1       392096   12.4750         E121        S     train
# 759      0       110152   86.5000          B77        S     train
# 763      2       113760  120.0000      B96 B98        S     train
# 765      0        13502   77.9583          D11        S     train
# 772      0  S.O./P.P. 3   10.5000          E77        S     train
# 776      0       383121    7.7500          F38        Q     train
# 779      1        24160  211.3375           B3        S     train
# 781      0        17474   57.0000          B20        S     train
# 782      0       113501   30.0000           D6        S     train
# 789      0     PC 17593   79.2000      B82 B84        C     train
# 796      0        17465   25.9292          D17        S     train
# 802      2       113760  120.0000      B96 B98        S     train
# 806      0       112050    0.0000          A36        S     train
# 809      0       113806   53.1000           E8        S     train
# 815      0       112058    0.0000         B102        S     train
# 820      1        12749   93.5000          B69        S     train
# 823      1       392096   12.4750         E121        S     train
# 829      0       113572   80.0000          B28      NaN     train
# 835      1     PC 17756   83.1583          E49        C     train
# 839      0        11774   29.7000          C47        C     train
# 849      0        17453   89.1042          C92        C     train
# 853      1     PC 17592   39.4000          D28        S     train
# 857      0       113055   26.5500          E17        S     train
# 862      0        17466   25.9292          D17        S     train
# 867      0     PC 17590   50.4958          A24        S     train
# 871      1        11751   52.5542          D35        S     train
# 872      0          695    5.0000  B51 B53 B55        S     train
# 879      1        11767   83.1583          C50        C     train
# 887      0       112053   30.0000          B42        S     train
# 889      0       111369   30.0000         C148        C     train
#
# [204 rows x 13 columns]

# %% [markdown]
# ### 苗字を取得

# %%
df_all["surname"] = df_all["Name"].apply(lambda x:x.split(",")[0])

# %% [markdown]
# ### 苗字のユニーク数をカウントして、可視化

# %%
data_counts = df_all['surname'].value_counts()[:50]
plt.figure(figsize=(12, 12))
sns.barplot(x=data_counts.values, y=data_counts.index)
plt.title('surnameの分布', fontsize=20)
plt.show()

# %% [markdown]
# ### 苗字を限定したデータでいくつか見てみる

# %%
df_all[df_all["surname"] == data_counts.index[0]]
# Out:
#        Age Cabin Embarked   Fare                               Name  Parch  \
# 159    NaN   NaN        S  69.55         Sage, Master. Thomas Henry      2
# 180    NaN   NaN        S  69.55       Sage, Miss. Constance Gladys      2
# 201    NaN   NaN        S  69.55                Sage, Mr. Frederick      2
# 324    NaN   NaN        S  69.55           Sage, Mr. George John Jr      2
# 792    NaN   NaN        S  69.55            Sage, Miss. Stella Anna      2
# 846    NaN   NaN        S  69.55           Sage, Mr. Douglas Bullen      2
# 863    NaN   NaN        S  69.55  Sage, Miss. Dorothy Edith "Dolly"      2
# 1079   NaN   NaN        S  69.55                    Sage, Miss. Ada      2
# 1233   NaN   NaN        S  69.55              Sage, Mr. John George      9
# 1251  14.5   NaN        S  69.55        Sage, Master. William Henry      2
# 1256   NaN   NaN        S  69.55     Sage, Mrs. John (Annie Bullen)      9
#
#       PassengerId  Pclass     Sex  SibSp  Survived    Ticket data_type surname
# 159           160       3    male      8         0  CA. 2343     train    Sage
# 180           181       3  female      8         0  CA. 2343     train    Sage
# 201           202       3    male      8         0  CA. 2343     train    Sage
# 324           325       3    male      8         0  CA. 2343     train    Sage
# 792           793       3  female      8         0  CA. 2343     train    Sage
# 846           847       3    male      8         0  CA. 2343     train    Sage
# 863           864       3  female      8         0  CA. 2343     train    Sage
# 1079         1080       3  female      8         1  CA. 2343      test    Sage
# 1233         1234       3    male      1         0  CA. 2343      test    Sage
# 1251         1252       3    male      8         0  CA. 2343      test    Sage
# 1256         1257       3  female      1         1  CA. 2343      test    Sage

# %%
df_all[df_all["surname"] == data_counts.index[22]]
# Out:
#       Age Cabin Embarked    Fare  \
# 165   9.0   NaN        S  20.525
# 328  31.0   NaN        S  20.525
# 548  33.0   NaN        S  20.525
# 933  41.0   NaN        S   7.850
#
#                                                 Name  Parch  PassengerId  \
# 165  Goldsmith, Master. Frank John William "Frankie"      2          166
# 328   Goldsmith, Mrs. Frank John (Emily Alice Brown)      1          329
# 548                        Goldsmith, Mr. Frank John      1          549
# 933                            Goldsmith, Mr. Nathan      0          934
#
#      Pclass     Sex  SibSp  Survived              Ticket data_type    surname
# 165       3    male      0         1              363291     train  Goldsmith
# 328       3  female      1         1              363291     train  Goldsmith
# 548       3    male      1         0              363291     train  Goldsmith
# 933       3    male      0         0  SOTON/O.Q. 3101263      test  Goldsmith

# %%
df_all[df_all["Ticket"] == data_counts.index[4]]
# Out:
#       Age Cabin Embarked    Fare  \
# 13   39.0   NaN        S  31.275
# 119   2.0   NaN        S  31.275
# 541   9.0   NaN        S  31.275
# 542  11.0   NaN        S  31.275
# 610  39.0   NaN        S  31.275
# 813   6.0   NaN        S  31.275
# 850   4.0   NaN        S  31.275
#
#                                                   Name  Parch  PassengerId  \
# 13                         Andersson, Mr. Anders Johan      5           14
# 119                  Andersson, Miss. Ellis Anna Maria      2          120
# 541               Andersson, Miss. Ingeborg Constanzia      2          542
# 542                  Andersson, Miss. Sigrid Elisabeth      2          543
# 610  Andersson, Mrs. Anders Johan (Alfrida Konstant...      5          611
# 813                 Andersson, Miss. Ebba Iris Alfrida      2          814
# 850            Andersson, Master. Sigvard Harald Elias      2          851
#
#      Pclass     Sex  SibSp  Survived  Ticket    surname
# 13        3    male      1         0  347082  Andersson
# 119       3  female      4         0  347082  Andersson
# 541       3  female      4         0  347082  Andersson
# 542       3  female      4         0  347082  Andersson
# 610       3  female      1         0  347082  Andersson
# 813       3  female      4         0  347082  Andersson
# 850       3    male      4         0  347082  Andersson

# %%
#parchが2→両親と乗っていると判断＝子供の可能性高い
df_all[(df_all["Parch"] == 2) & (df_all["SibSp"] > 2)]
# Out:
#        Age        Cabin Embarked      Fare  \
# 27    19.0  C23 C25 C27        S  263.0000
# 59    11.0          NaN        S   46.9000
# 63     4.0          NaN        S   27.9000
# 68    17.0          NaN        S    7.9250
# 71    16.0          NaN        S   46.9000
# 88    23.0  C23 C25 C27        S  263.0000
# 119    2.0          NaN        S   31.2750
# 159    NaN          NaN        S   69.5500
# 180    NaN          NaN        S   69.5500
# 182    9.0          NaN        S   31.3875
# 201    NaN          NaN        S   69.5500
# 233    5.0          NaN        S   31.3875
# 261    3.0          NaN        S   31.3875
# 324    NaN          NaN        S   69.5500
# 341   24.0  C23 C25 C27        S  263.0000
# 386    1.0          NaN        S   46.9000
# 480    9.0          NaN        S   46.9000
# 541    9.0          NaN        S   31.2750
# 542   11.0          NaN        S   31.2750
# 634    9.0          NaN        S   27.9000
# 642    2.0          NaN        S   27.9000
# 683   14.0          NaN        S   46.9000
# 792    NaN          NaN        S   69.5500
# 813    6.0          NaN        S   31.2750
# 819   10.0          NaN        S   27.9000
# 846    NaN          NaN        S   69.5500
# 850    4.0          NaN        S   31.2750
# 863    NaN          NaN        S   69.5500
# 944   28.0  C23 C25 C27        S  263.0000
# 1031  10.0          NaN        S   46.9000
# 1045  13.0          NaN        S   31.3875
# 1079   NaN          NaN        S   69.5500
# 1105  38.0          NaN        S    7.7750
# 1251  14.5          NaN        S   69.5500
# 1270   5.0          NaN        S   31.3875
#
#                                          Name  Parch  PassengerId  Pclass  \
# 27             Fortune, Mr. Charles Alexander      2           28       1
# 59         Goodwin, Master. William Frederick      2           60       3
# 63                      Skoog, Master. Harald      2           64       3
# 68            Andersson, Miss. Erna Alexandra      2           69       3
# 71                 Goodwin, Miss. Lillian Amy      2           72       3
# 88                 Fortune, Miss. Mabel Helen      2           89       1
# 119         Andersson, Miss. Ellis Anna Maria      2          120       3
# 159                Sage, Master. Thomas Henry      2          160       3
# 180              Sage, Miss. Constance Gladys      2          181       3
# 182     Asplund, Master. Clarence Gustaf Hugo      2          183       3
# 201                       Sage, Mr. Frederick      2          202       3
# 233            Asplund, Miss. Lillian Gertrud      2          234       3
# 261         Asplund, Master. Edvin Rojj Felix      2          262       3
# 324                  Sage, Mr. George John Jr      2          325       3
# 341            Fortune, Miss. Alice Elizabeth      2          342       1
# 386           Goodwin, Master. Sidney Leonard      2          387       3
# 480            Goodwin, Master. Harold Victor      2          481       3
# 541      Andersson, Miss. Ingeborg Constanzia      2          542       3
# 542         Andersson, Miss. Sigrid Elisabeth      2          543       3
# 634                        Skoog, Miss. Mabel      2          635       3
# 642             Skoog, Miss. Margit Elizabeth      2          643       3
# 683               Goodwin, Mr. Charles Edward      2          684       3
# 792                   Sage, Miss. Stella Anna      2          793       3
# 813        Andersson, Miss. Ebba Iris Alfrida      2          814       3
# 819              Skoog, Master. Karl Thorsten      2          820       3
# 846                  Sage, Mr. Douglas Bullen      2          847       3
# 850   Andersson, Master. Sigvard Harald Elias      2          851       3
# 863         Sage, Miss. Dorothy Edith "Dolly"      2          864       3
# 944                Fortune, Miss. Ethel Flora      2          945       1
# 1031              Goodwin, Miss. Jessie Allis      2         1032       3
# 1045             Asplund, Master. Filip Oscar      2         1046       3
# 1079                          Sage, Miss. Ada      2         1080       3
# 1105   Andersson, Miss. Ida Augusta Margareta      2         1106       3
# 1251              Sage, Master. William Henry      2         1252       3
# 1270              Asplund, Master. Carl Edgar      2         1271       3
#
#          Sex  SibSp  Survived    Ticket    surname
# 27      male      3         0     19950    Fortune
# 59      male      5         0   CA 2144    Goodwin
# 63      male      3         0    347088      Skoog
# 68    female      4         1   3101281  Andersson
# 71    female      5         0   CA 2144    Goodwin
# 88    female      3         1     19950    Fortune
# 119   female      4         0    347082  Andersson
# 159     male      8         0  CA. 2343       Sage
# 180   female      8         0  CA. 2343       Sage
# 182     male      4         0    347077    Asplund
# 201     male      8         0  CA. 2343       Sage
# 233   female      4         1    347077    Asplund
# 261     male      4         1    347077    Asplund
# 324     male      8         0  CA. 2343       Sage
# 341   female      3         1     19950    Fortune
# 386     male      5         0   CA 2144    Goodwin
# 480     male      5         0   CA 2144    Goodwin
# 541   female      4         0    347082  Andersson
# 542   female      4         0    347082  Andersson
# 634   female      3         0    347088      Skoog
# 642   female      3         0    347088      Skoog
# 683     male      5         0   CA 2144    Goodwin
# 792   female      8         0  CA. 2343       Sage
# 813   female      4         0    347082  Andersson
# 819     male      3         0    347088      Skoog
# 846     male      8         0  CA. 2343       Sage
# 850     male      4         0    347082  Andersson
# 863   female      8         0  CA. 2343       Sage
# 944   female      3         2     19950    Fortune
# 1031  female      5         2   CA 2144    Goodwin
# 1045    male      4         2    347077    Asplund
# 1079  female      8         2  CA. 2343       Sage
# 1105  female      4         2    347091  Andersson
# 1251    male      8         2  CA. 2343       Sage
# 1270    male      4         2    347077    Asplund

# %%
#苗字、性別、出港地をカテゴリ変数化
cols = ["surname", "Sex","Embarked"]
df_all_to_cat = pd.get_dummies(df_all, columns=cols)
print(df_all_to_cat.shape)
# Out:
# (1309, 890)

# %%
#苗字のうち、ユニーク数が1のものを除く
data_counts = df_all['surname'].value_counts()
surname_to_drop = data_counts[data_counts < 3].index.tolist()

to_drop_list = []
target_col = "surname"

for each_data in surname_to_drop:
    col_name = "{}_{}".format(target_col,each_data)
    to_drop_list.append(col_name)
    
df_all_to_cat.drop(columns=to_drop_list, inplace=True)

# %%
#その他、不要なカラムを削除
to_drop = ["PassengerId","Name","Ticket","Cabin"]

df_all_to_cat.drop(columns=to_drop, inplace=True)
print(df_all_to_cat.shape)
# Out:
# (1309, 116)

# %%
#年齢の欠損値を平均で埋める
df_all_to_cat['Age'].fillna(df_all_to_cat['Age'].mode()[0], inplace=True)

# %%
#説明変数と目的変数に分離
y_all = df_train_surname_to_cat.iloc[:,0].values
x_all = df_train_surname_to_cat.iloc[:,1:].values
